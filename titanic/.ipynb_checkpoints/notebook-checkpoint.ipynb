# %%
# Imports
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

from sklearn.ensemble import RandomForestRegressor as RFR
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %%
# Import dataset
df = pd.read_csv("data/train.csv", index_col="PassengerId")
df.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
# Chech columns
df.columns.to_list()
# Out:
# ['Survived',
#  'Pclass',
#  'Name',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Cabin',
#  'Embarked']

# %%
# Describe
df.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
# Drop probably useless columns
df.drop(["Name", "Ticket"], axis=1, inplace=True)
df.head()
# Out:
#              Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin  \
# PassengerId
# 1                   0       3    male  22.0      1      0   7.2500   NaN
# 2                   1       1  female  38.0      1      0  71.2833   C85
# 3                   1       3  female  26.0      0      0   7.9250   NaN
# 4                   1       1  female  35.0      1      0  53.1000  C123
# 5                   0       3    male  35.0      0      0   8.0500   NaN
#
#             Embarked
# PassengerId
# 1                  S
# 2                  C
# 3                  S
# 4                  S
# 5                  S

# %%
# Make 'Sex' and 'Embarked' cols numeric
df["Sex"] = df["Sex"].map({"male": 1, "female": 0})
df["Embarked"] = df["Embarked"].map({"S": 0, "C": 1, "Q": 2})
df.head()
# Out:
#              Survived  Pclass  Sex   Age  SibSp  Parch     Fare Cabin  \
# PassengerId
# 1                   0       3    1  22.0      1      0   7.2500   NaN
# 2                   1       1    0  38.0      1      0  71.2833   C85
# 3                   1       3    0  26.0      0      0   7.9250   NaN
# 4                   1       1    0  35.0      1      0  53.1000  C123
# 5                   0       3    1  35.0      0      0   8.0500   NaN
#
#              Embarked
# PassengerId
# 1                 0.0
# 2                 1.0
# 3                 0.0
# 4                 0.0
# 5                 0.0

# %%
# Check for number of unique values
df.nunique(axis=0)
# Out:
# Survived      2
# Pclass        3
# Sex           2
# Age          88
# SibSp         7
# Parch         7
# Fare        248
# Cabin       147
# Embarked      3
# dtype: int64

# %%
# Check for NaNs
df.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
# Let's drop Cabin col and NaNs in Embarked
df.drop("Cabin", axis=1, inplace=True)
df.dropna(subset=["Embarked"], axis=0, inplace=True)
df.head()
# Out:
#              Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# PassengerId
# 1                   0       3    1  22.0      1      0   7.2500       0.0
# 2                   1       1    0  38.0      1      0  71.2833       1.0
# 3                   1       3    0  26.0      0      0   7.9250       0.0
# 4                   1       1    0  35.0      1      0  53.1000       0.0
# 5                   0       3    1  35.0      0      0   8.0500       0.0

# %%
# Plot age values distribution
df["Age"].plot(kind="hist")
plt.show()

# %%
# Let's study correlations
corr = df.corr(method="spearman")
corr = corr[(corr <= -0.3) | (corr >= 0.3)]
ax = sns.heatmap(corr, annot=True, linewidth=.5)
ax.set(xlabel="", ylabel="")
plt.show()

# %%
# Let's plot age dist per class, which is the only feat correlated with age
fig, ax = plt.subplots(1, 3, figsize=(15, 5))
for pc in [1,2,3]:
    df_tmp = df[df["Pclass"] == pc]
    ax[pc-1].hist(df_tmp["Age"], label="class: " + str(pc))
    ax[pc-1].legend()
    ax[pc-1].set_xlabel("Age")
plt.show()

# %%
# Let's sample for the age dist in each class to impute age values (improve code here)
dfs = []
for pc in [1,2,3]:
    df_tmp = df[df["Pclass"] == pc].copy()
    num_nan = df_tmp["Age"].isnull().sum() 
    vals = np.random.choice(df_tmp["Age"].dropna().values, size=num_nan)
    for i, ii in enumerate(df_tmp.loc[df_tmp["Age"].isnull()].index):
        df_tmp["Age"].loc[ii] = vals[i]
    dfs.append(df_tmp)
df = pd.concat(dfs)

# Plot distributions
fig, ax = plt.subplots(1, 3, figsize=(15, 5))
for pc in [1,2,3]:
    df_tmp = df[df["Pclass"] == pc]
    ax[pc-1].hist(df_tmp["Age"], label="class: " + str(pc))
    ax[pc-1].legend()
    ax[pc-1].set_xlabel("Age")
plt.show()
# Out:
#              Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# PassengerId
# 2                   1       1    0  38.0      1      0  71.2833       1.0
# 4                   1       1    0  35.0      1      0  53.1000       0.0
# 7                   0       1    1  54.0      0      0  51.8625       0.0
# 12                  1       1    0  58.0      0      0  26.5500       0.0
# 24                  1       1    1  28.0      0      0  35.5000       0.0
